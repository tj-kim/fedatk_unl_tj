# %% [markdown]
# ### Multiround UNL Attack Mixed
#
# Figure 5abc, and 6c
# Adjust the aggregation method accordingly based on hyperparameters (trimmed mean cutoff) to replicate results
#
# Can also use this code to perform experiments for table 2
#
# ##### Summary
# Load FAT model trained for 150 rounds and for 50 rounds try and inject FedAvg model into the system. Try different scaling rates and spread out the model replacement attack.

# %%
cd /home/ubuntu/fedatk_unl_tj/
# Out:
# /home/ubuntu/fedatk_unl_tj

# %%
# Import General Libraries
import os
import argparse
import torch
import copy
import pickle
import random
import numpy as np
import pandas as pd

# Import FedEM based Libraries
from utils.utils import *
from utils.constants import *
from utils.args import *
from utils.util_notebooks import *
from run_experiment import *
from models import *

# Import Transfer Attack
from transfer_attacks.Personalized_NN import *
from transfer_attacks.Params import *
from transfer_attacks.Transferer import *
from transfer_attacks.Args import *
from transfer_attacks.TA_utils import *
# Out:
# /home/ubuntu/anaconda3/envs/FedEM_env/lib/python3.9/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /home/ubuntu/anaconda3/envs/FedEM_env/lib/python3.9/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.2' currently installed).
#   from pandas.core import (

# %%
# Specify aggregation method, number of clients, and dataset
setting, num_user = "FedAvg_adv", 50
exp = "cifar100"

# Load models for FAT and FedAvg - write down path to where weights are saved
save_path_FAT = '/home/ubuntu/fedatk_unl_tj/weights/cifar100/250123_icml25/FAT/'
save_path_FedAvg =  '/home/ubuntu/fedatk_unl_tj/weights/cifar100/250123_icml25/FedAvg/'
save_path_FedAvg_150R = '/home/ubuntu/fedatk_unl_tj/weights/cifar100/250123_icml25/FAT_R50/'

# save_path_FAT = '/home/ubuntu/fedatk_unl_tj/weights/fakenews/250119_small_architecture_moreconv/FAT_ep02/'
# save_path_FedAvg =  '/home/ubuntu/fedatk_unl_tj/weights/fakenews/250119_small_architecture_moreconv/FedAvg/'

# Attack parameters for performing PGD 
eps_attack = 4.0
eps_train = 4.5
step_size = 0.01
steps = 10

# %%
# Generate instance of aggregator that holds all clients, data and models and load relevant models in
try: # Skip loading if already loaded
    aggregator_og
except:
    aggregator_og, clients, args_ = set_args(setting, num_user,  experiment = exp) # Indicate dataset here

model_FAT = copy.deepcopy(import_model_weights(num_user, setting, save_path_FAT, aggregator_og, args_)[0])
model_Fedavg = copy.deepcopy(import_model_weights(num_user, setting, save_path_FedAvg, aggregator_og, args_)[0])

# Obtain parameters for each layer
params_FAT = model_FAT.state_dict()
params_FedAvg = model_Fedavg.state_dict()

# Just take the values of weights and bias for the model
desired_keys = params_FAT.keys() # [key for key in params_FAT.keys() if 'weight' in key or '
# Out:
# ==> Clients initialization..
# ===> Building data iterators..
#  49%|████▉     | 49/100 [00:00<00:00, 185.56it/s]
# ===> Initializing clients..
#   0%|          | 0/50 [00:00<?, ?it/s]/home/ubuntu/anaconda3/envs/FedEM_env/lib/python3.9/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/ubuntu/anaconda3/envs/FedEM_env/lib/python3.9/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=MobileNet_V2_Weights.IMAGENET1K_V1`. You can also use `weights=MobileNet_V2_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# 100%|██████████| 50/50 [00:19<00:00,  2.58it/s]
# /home/ubuntu/fedatk_unl_tj/aggregator.py:289: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   learner.model.load_state_dict(torch.load(chkpts_path))

# %%
num_aru = [15, 20, 25, 30]
beta_params = [0.05, 0.05, 0.05, 0.05]
weight2_list = [0.1, 0.1, 0.1, 0.1]
agg_options = ["median", "median", "median", "median"]

num_rounds = 20
eps = eps_attack

result_list = []
for itt in range(len(num_aru)):
    result_list += [{}]

# setting, num_user = "FedAvg_adv", 20
aggregator, clients, args_ = set_args(setting, num_user,  experiment = exp)

agg_choice = random.choices(range(3),k=num_rounds)

if True:
    print("updating adv data set")
    # add adv dataset update
    Fu = np.zeros(num_user)
    Fu[0:25] = 1

    # Setting evasion attack parameters
    x_min = torch.min(clients[0].adv_nn.dataloader.x_data)
    x_max = torch.max(clients[0].adv_nn.dataloader.x_data)
    atk_params = PGD_Params()
    atk_params.set_params(batch_size=1, iteration = 10,
                    target = -1, x_val_min = x_min, x_val_max = x_max,
                    step_size = 0.05, step_norm = "inf", eps = eps, eps_norm = 2)

    # Assign proportion and attack params
    for c in range(len(clients)):
        if Fu[c] > 0:
            aggregator.clients[c].set_adv_params(Fu[c], atk_params)
            aggregator.clients[c].update_advnn()
            aggregator.clients[c].assign_advdataset()

for itt in range(len(beta_params)):
    # Perform 50 rounds of FAT on FedAvg model 
    num_adv = num_aru[itt]
    weight2_temp = weight2_list[itt]
    adv_id = random.sample(range(num_user), num_adv) # excluding 0-9 as Fu = 1
    beta = beta_params[itt]

    test_acc_gather = []
    adv_acc_gather = []
    test_acc_std = []
    adv_acc_std = []
    cosine_gather_layers = np.zeros([num_rounds, len(desired_keys)])

    aggregator.tm_rate = beta

    # Test performance of aggregator on data 
    aggregator.load_state(dir_path = save_path_FedAvg_150R)
    aggregator.update_clients()
    model_FA = pull_model_from_agg(aggregator)
    model_FA.eval()
    acc, adv_acc = get_adv_acc(aggregator, model_FA, eps = eps)

    # prev_model = copy.deepcopy(model_FA)

    print("Test acc: ", np.mean(acc), "adv acc: ", np.mean(adv_acc))
    test_acc_gather+= [np.mean(acc)]
    adv_acc_gather += [np.mean(adv_acc)]
    test_acc_std += [np.std(acc)]
    adv_acc_std += [np.std(adv_acc)]



    for i in range(num_rounds):
        weight2 = 1/num_adv * weight2_temp
        # Per round Freq
        aggregator.aggregation_op = agg_options[itt]

        # aggregator.mix()
        UNL_mix(aggregator, adv_id, model_inject = model_Fedavg, keys = desired_keys, weight_scale_2 = weight2, dump_flag=False, tm_beta=beta)
        model_overfit = pull_model_from_agg(aggregator)
        model_overfit.eval()
        acc, adv_acc = get_adv_acc(aggregator, model_overfit, eps = eps)

        print("round", i,"Test acc: ", np.mean(acc), "adv acc: ", np.mean(adv_acc))
        test_acc_gather+= [np.mean(acc)]
        adv_acc_gather += [np.mean(adv_acc)]
        test_acc_std += [np.std(acc)]
        adv_acc_std += [np.std(adv_acc)]
        # prev_model = copy.deepcopy(model_overfit)

        result_list[itt]['test_acc'] = copy.deepcopy(test_acc_gather)
        result_list[itt]['adv_acc'] = copy.deepcopy(adv_acc_gather)
        result_list[itt]['test_std'] = copy.deepcopy(test_acc_std)
        result_list[itt]['adv_std'] = copy.deepcopy(adv_acc_std)
        result_list[itt]['num_clients'] = num_adv
        result_list[itt]['beta'] = beta
        result_list[itt]['weight2'] = weight2_list[itt]
        # Perform gradient direction gathering

        # dynamic application of weight 2
        weight2_temp += 0.1
        if weight2_temp > 1:
            weight2_temp = 1

        del model_overfit
        gc.collect()
        torch.cuda.empty_cache()
# Out:
# ==> Clients initialization..
# ===> Building data iterators..
#  49%|████▉     | 49/100 [00:00<00:00, 258.37it/s]
# ===> Initializing clients..
# 100%|██████████| 50/50 [00:16<00:00,  3.01it/s]
# updating adv data set
# Test acc:  0.4156666654348373 adv acc:  0.10466666858643293
# /home/ubuntu/fedatk_unl_tj/learners/learner.py:192: UserWarning: The use of `x.T` on tensors of dimension other than 2 to reverse their shape is deprecated and it will throw an error in a future release. Consider `x.mT` to transpose batches of matrices or `x.permute(*torch.arange(x.ndim - 1, -1, -1))` to reverse the dimensions of a tensor. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3683.)
#   loss = (loss_vec.T @ weights[indices]) / loss_vec.size(0)
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 0 Test acc:  0.4156666660308838 adv acc:  0.10266666885465384
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 1 Test acc:  0.4153333359956741 adv acc:  0.10033333513885737
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 2 Test acc:  0.41649999856948855 adv acc:  0.09633333537727594
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 3 Test acc:  0.41683333218097685 adv acc:  0.0940000018849969
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 4 Test acc:  0.41433333456516264 adv acc:  0.08916666846722364
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 5 Test acc:  0.4151666682958603 adv acc:  0.08666666861623526
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 6 Test acc:  0.41116666853427886 adv acc:  0.08583333525806665
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 7 Test acc:  0.41116666436195376 adv acc:  0.08516666833311319
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 8 Test acc:  0.41133333086967466 adv acc:  0.08516666851937771
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 9 Test acc:  0.41149999618530275 adv acc:  0.084333335198462
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 10 Test acc:  0.4074999988079071 adv acc:  0.08250000201165676
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 11 Test acc:  0.4071666646003723 adv acc:  0.08366666838526726
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 12 Test acc:  0.40750000059604646 adv acc:  0.08016666866838933
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 13 Test acc:  0.4071666669845581 adv acc:  0.08050000213086606
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 14 Test acc:  0.4064999997615814 adv acc:  0.0788333348929882
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 15 Test acc:  0.4056666648387909 adv acc:  0.0776666684448719
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 16 Test acc:  0.4046666669845581 adv acc:  0.07883333515375852
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 17 Test acc:  0.4044999998807907 adv acc:  0.07650000184774398
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 18 Test acc:  0.40383333384990694 adv acc:  0.0768333351612091
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 19 Test acc:  0.40333333492279055 adv acc:  0.07566666824743151
# Test acc:  0.4156666654348373 adv acc:  0.10283333506435156
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 0 Test acc:  0.4155000001192093 adv acc:  0.10266666833311319
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 1 Test acc:  0.416333332657814 adv acc:  0.10300000164657831
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 2 Test acc:  0.4156666660308838 adv acc:  0.10416666854172946
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 3 Test acc:  0.415333331823349 adv acc:  0.10200000192970038
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 4 Test acc:  0.41149999797344206 adv acc:  0.10050000209361315
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 5 Test acc:  0.4118333315849304 adv acc:  0.10100000184029341
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 6 Test acc:  0.4094999992847443 adv acc:  0.09783333506435156
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 7 Test acc:  0.40683333337306976 adv acc:  0.09683333527296782
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 8 Test acc:  0.40716666489839554 adv acc:  0.09583333488553762
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 9 Test acc:  0.4063333323597908 adv acc:  0.09516666863113642
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 10 Test acc:  0.4039999994635582 adv acc:  0.09450000133365392
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 11 Test acc:  0.400999998152256 adv acc:  0.09333333533257246
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 12 Test acc:  0.39966666609048845 adv acc:  0.09366666879504919
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 13 Test acc:  0.3991666680574417 adv acc:  0.09200000155717135
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 14 Test acc:  0.3981666660308838 adv acc:  0.08983333516865968
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 15 Test acc:  0.3953333342075348 adv acc:  0.08800000187009573
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 16 Test acc:  0.395 adv acc:  0.08716666843742132
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 17 Test acc:  0.39499999940395353 adv acc:  0.08583333533257247
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 18 Test acc:  0.3958333331346512 adv acc:  0.0848333351686597
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 19 Test acc:  0.3948333340883255 adv acc:  0.08300000179558992
# Test acc:  0.4156666654348373 adv acc:  0.10333333525806665
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 0 Test acc:  0.4159999990463257 adv acc:  0.10283333491533994
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 1 Test acc:  0.4173333311080933 adv acc:  0.10166666824370622
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 2 Test acc:  0.41683333218097685 adv acc:  0.10233333542943
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 3 Test acc:  0.4106666657328606 adv acc:  0.10233333449810743
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 4 Test acc:  0.40783333390951154 adv acc:  0.09983333546668291
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 5 Test acc:  0.40499999970197675 adv acc:  0.09983333494514227
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 6 Test acc:  0.40433333307504654 adv acc:  0.09616666801273822
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 7 Test acc:  0.3964999997615814 adv acc:  0.09433333519846201
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 8 Test acc:  0.39583333164453505 adv acc:  0.08983333516865968
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 9 Test acc:  0.3883333346247673 adv acc:  0.0855000014975667
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 10 Test acc:  0.3833333337306976 adv acc:  0.08066666841506959
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 11 Test acc:  0.3769999983906746 adv acc:  0.0780000015720725
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 12 Test acc:  0.3723333299160004 adv acc:  0.0733333351649344
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 13 Test acc:  0.3711666634678841 adv acc:  0.07100000176578761
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 14 Test acc:  0.3684999990463257 adv acc:  0.06883333455771208
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 15 Test acc:  0.3678333324193954 adv acc:  0.06733333498239517
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 16 Test acc:  0.3653333327174187 adv acc:  0.06416666831821204
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 17 Test acc:  0.3660000005364418 adv acc:  0.060666668135672806
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 18 Test acc:  0.3641666668653488 adv acc:  0.060333334915339945
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 19 Test acc:  0.3626666679978371 adv acc:  0.057166668362915514
# Test acc:  0.4156666654348373 adv acc:  0.102666668407619
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 0 Test acc:  0.4164999973773956 adv acc:  0.1025000024214387
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 1 Test acc:  0.417833331823349 adv acc:  0.10283333521336317
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 2 Test acc:  0.4188333338499069 adv acc:  0.09966666843742132
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 3 Test acc:  0.419833333492279 adv acc:  0.100166668407619
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 4 Test acc:  0.42033333659172056 adv acc:  0.09700000185519457
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 5 Test acc:  0.41933333516120913 adv acc:  0.09450000159442425
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 6 Test acc:  0.4201666682958603 adv acc:  0.09283333521336318
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 7 Test acc:  0.4181666660308838 adv acc:  0.08916666891425848
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 8 Test acc:  0.41799999952316286 adv acc:  0.08516666863113642
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 9 Test acc:  0.41750000059604647 adv acc:  0.08133333496749401
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 10 Test acc:  0.418999999165535 adv acc:  0.0773333353176713
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 11 Test acc:  0.4184999996423721 adv acc:  0.0738333348557353
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 12 Test acc:  0.41666666567325594 adv acc:  0.07083333529531956
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 13 Test acc:  0.4174999982118607 adv acc:  0.06950000170618295
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 14 Test acc:  0.4181666654348373 adv acc:  0.06533333498984575
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 15 Test acc:  0.417833331823349 adv acc:  0.06150000177323818
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 16 Test acc:  0.4181666624546051 adv acc:  0.05733333485201001
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 17 Test acc:  0.418999999165535 adv acc:  0.05433333477005362
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 18 Test acc:  0.4183333343267441 adv acc:  0.051000001393258575
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 19 Test acc:  0.4181666702032089 adv acc:  0.04816666772589087

# %%
import pickle

a = result_list

with open('saved_results/mixed_sweep/250127_5c1_median_arui_dynamicbeta_cifar100.pk', 'wb') as handle:
    pickle.dump(a, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
# with open('saved_results/mixed_sweep/250127_5c1_median_arui_dynamicbeta_cifar100.pk', 'rb') as handle:
#     result_list = pickle.load(handle)

# %%
import matplotlib.pyplot as plt
import numpy as np

font = {'family' : 'normal',
        'weight' : 'normal',
        'size'   : 18}

plt.rc('font', **font)
plt.figure(dpi=80, figsize=(6,4))

plot_settings = [ [15, "0.1 - 1.0"], [20, "0.1 - 1.0"], [25, "0.1 - 1.0"], [30, "0.1 - 1.0"]]

num_aru = [15, 20, 25, 30]
beta_params = [0.05, 0.05, 0.05, 0.05]
weight2_list = [0.1, 0.1, 0.1, 0.1]
agg_options = ["median", "median", "median", "median"]

# Generate some sample data
x = range(num_rounds+1)  # 100 points from 0 to 10

# Plotting the lines
# plt.plot(x, y1, label='Test Acc')
label_list = plot_settings
for i in range(len(label_list)):
    y = np.array(result_list[i]['adv_acc'])
    error = np.array(result_list[i]['adv_std'])
    plt.plot(x, y, label= str(label_list[i]))
    plt.fill_between(x, y-error, y+error,
    alpha=0.2)

# Adding labels and title
plt.xlabel('Injection Rounds')
plt.ylabel('Adv. Acc. (Robustness)')
plt.title('CIFAR-100: ARU vs Median \n Legend - [#ARU client, β]', fontsize = 'medium')

# Adding a legend
plt.legend( loc="best", fontsize=14)


# Display the plot
plt.show()

# %% [raw]
# 'saved_results/mixed_sweep/250127_5c1_median_arui_dynamicbeta.pk'
# plot_settings = [[10, "0.1 - 1.0"], [15, "0.1 - 1.0"], [17, "0.1 - 1.0"], [20, "0.1 - 1.0"], [25, "0.1 - 1.0"]]
