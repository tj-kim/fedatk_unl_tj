# %% [markdown]
# ### Multiround UNL Attack Mixed
#
# Figure 5abc, and 6c
# Adjust the aggregation method accordingly based on hyperparameters (trimmed mean cutoff) to replicate results
#
# Can also use this code to perform experiments for table 2
#
# ##### Summary
# Load FAT model trained for 150 rounds and for 50 rounds try and inject FedAvg model into the system. Try different scaling rates and spread out the model replacement attack.

# %%
cd /home/ubuntu/fedatk_unl_tj/
# Out:
# /home/ubuntu/fedatk_unl_tj

# %%
# Import General Libraries
import os
import argparse
import torch
import copy
import pickle
import random
import numpy as np
import pandas as pd

# Import FedEM based Libraries
from utils.utils import *
from utils.constants import *
from utils.args import *
from utils.util_notebooks import *
from run_experiment import *
from models import *

# Import Transfer Attack
from transfer_attacks.Personalized_NN import *
from transfer_attacks.Params import *
from transfer_attacks.Transferer import *
from transfer_attacks.Args import *
from transfer_attacks.TA_utils import *
# Out:
# /home/ubuntu/anaconda3/envs/FedEM_env/lib/python3.9/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /home/ubuntu/anaconda3/envs/FedEM_env/lib/python3.9/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.2' currently installed).
#   from pandas.core import (

# %%
# Specify aggregation method, number of clients, and dataset
setting, num_user = "FedAvg_adv", 40
exp = "cifar10"

# Load models for FAT and FedAvg - write down path to where weights are saved
save_path_FAT = '/home/ubuntu/fedatk_unl_tj/weights/cifar10/250123_icml25/FAT/'
save_path_FedAvg =  '/home/ubuntu/fedatk_unl_tj/weights/cifar10/250123_icml25/FedAvg/'
# save_path_FAT = '/home/ubuntu/fedatk_unl_tj/weights/fakenews/250119_small_architecture_moreconv/FAT_ep02/'
# save_path_FedAvg =  '/home/ubuntu/fedatk_unl_tj/weights/fakenews/250119_small_architecture_moreconv/FedAvg/'

# Attack parameters for performing PGD 
eps_attack = 4.0
eps_train = 4.5
step_size = 0.01
steps = 10

# %%
# Generate instance of aggregator that holds all clients, data and models and load relevant models in
try: # Skip loading if already loaded
    aggregator_og
except:
    aggregator_og, clients, args_ = set_args(setting, num_user,  experiment = exp) # Indicate dataset here

model_FAT = copy.deepcopy(import_model_weights(num_user, setting, save_path_FAT, aggregator_og, args_)[0])
model_Fedavg = copy.deepcopy(import_model_weights(num_user, setting, save_path_FedAvg, aggregator_og, args_)[0])

# Obtain parameters for each layer
params_FAT = model_FAT.state_dict()
params_FedAvg = model_Fedavg.state_dict()

# Just take the values of weights and bias for the model
desired_keys = params_FAT.keys() # [key for key in params_FAT.keys() if 'weight' in key or 'bias' in key] #
# Out:
# ==> Clients initialization..
# ===> Building data iterators..
#  49%|████▉     | 39/80 [00:00<00:00, 117.63it/s]
# ===> Initializing clients..
#   0%|          | 0/40 [00:00<?, ?it/s]/home/ubuntu/anaconda3/envs/FedEM_env/lib/python3.9/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/ubuntu/anaconda3/envs/FedEM_env/lib/python3.9/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=MobileNet_V2_Weights.IMAGENET1K_V1`. You can also use `weights=MobileNet_V2_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# 100%|██████████| 40/40 [00:24<00:00,  1.65it/s]
# /home/ubuntu/fedatk_unl_tj/aggregator.py:289: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   learner.model.load_state_dict(torch.load(chkpts_path))

# %%
num_aru = [10, 15, 17, 20, 25]
beta_params = [0.05, 0.05, 0.05, 0.05, 0.05]
weight2_list = [1, 1, 1, 1, 1]
agg_options = ["median", "median", "median", "median", "median"]

num_rounds = 15
eps = eps_attack

result_list = []
for itt in range(len(num_aru)):
    result_list += [{}]

# setting, num_user = "FedAvg_adv", 20
save_path_FedAvg_150R = '/home/ubuntu/fedatk_unl_tj/weights/cifar10/250123_icml25/FAT_R50/'
aggregator, clients, args_ = set_args(setting, num_user,  experiment = exp)

agg_choice = random.choices(range(3),k=num_rounds)

if True:
    print("updating adv data set")
    # add adv dataset update
    Fu = np.zeros(num_user)
    Fu[0:25] = 1

    # Setting evasion attack parameters
    x_min = torch.min(clients[0].adv_nn.dataloader.x_data)
    x_max = torch.max(clients[0].adv_nn.dataloader.x_data)
    atk_params = PGD_Params()
    atk_params.set_params(batch_size=1, iteration = 10,
                    target = -1, x_val_min = x_min, x_val_max = x_max,
                    step_size = 0.05, step_norm = "inf", eps = eps, eps_norm = 2)

    # Assign proportion and attack params
    for c in range(len(clients)):
        if Fu[c] > 0:
            aggregator.clients[c].set_adv_params(Fu[c], atk_params)
            aggregator.clients[c].update_advnn()
            aggregator.clients[c].assign_advdataset()

for itt in range(len(beta_params)):
    # Perform 50 rounds of FAT on FedAvg model 
    num_adv = num_aru[itt]
    weight2 = 1/num_adv * weight2_list[itt]
    adv_id = random.sample(range(num_user), num_adv) # excluding 0-9 as Fu = 1
    beta = beta_params[itt]

    test_acc_gather = []
    adv_acc_gather = []
    test_acc_std = []
    adv_acc_std = []
    cosine_gather_layers = np.zeros([num_rounds, len(desired_keys)])

    aggregator.tm_rate = beta

    # Test performance of aggregator on data 
    aggregator.load_state(dir_path = save_path_FedAvg_150R)
    aggregator.update_clients()
    model_FA = pull_model_from_agg(aggregator)
    model_FA.eval()
    acc, adv_acc = get_adv_acc(aggregator, model_FA, eps = eps)

    # prev_model = copy.deepcopy(model_FA)

    print("Test acc: ", np.mean(acc), "adv acc: ", np.mean(adv_acc))
    test_acc_gather+= [np.mean(acc)]
    adv_acc_gather += [np.mean(adv_acc)]
    test_acc_std += [np.std(acc)]
    adv_acc_std += [np.std(adv_acc)]



    for i in range(num_rounds):

        # Per round Freq
        aggregator.aggregation_op = agg_options[itt]

        # aggregator.mix()
        UNL_mix(aggregator, adv_id, model_inject = model_Fedavg, keys = desired_keys, weight_scale_2 = weight2, dump_flag=False, tm_beta=beta)
        model_overfit = pull_model_from_agg(aggregator)
        model_overfit.eval()
        acc, adv_acc = get_adv_acc(aggregator, model_overfit, eps = eps)

        print("round", i,"Test acc: ", np.mean(acc), "adv acc: ", np.mean(adv_acc))
        test_acc_gather+= [np.mean(acc)]
        adv_acc_gather += [np.mean(adv_acc)]
        test_acc_std += [np.std(acc)]
        adv_acc_std += [np.std(adv_acc)]
        # prev_model = copy.deepcopy(model_overfit)

        result_list[itt]['test_acc'] = copy.deepcopy(test_acc_gather)
        result_list[itt]['adv_acc'] = copy.deepcopy(adv_acc_gather)
        result_list[itt]['test_std'] = copy.deepcopy(test_acc_std)
        result_list[itt]['adv_std'] = copy.deepcopy(adv_acc_std)
        result_list[itt]['num_clients'] = num_adv
        result_list[itt]['beta'] = beta
        result_list[itt]['weight2'] = weight2_list[itt]
        # Perform gradient direction gathering

        del model_overfit
        gc.collect()
        torch.cuda.empty_cache()
# Out:
# ==> Clients initialization..
# ===> Building data iterators..
#  49%|████▉     | 39/80 [00:00<00:00, 115.14it/s]
# ===> Initializing clients..
# 100%|██████████| 40/40 [00:19<00:00,  2.09it/s]
# updating adv data set
# Test acc:  0.8062499985098839 adv acc:  0.39718749970197675
# /home/ubuntu/fedatk_unl_tj/learners/learner.py:192: UserWarning: The use of `x.T` on tensors of dimension other than 2 to reverse their shape is deprecated and it will throw an error in a future release. Consider `x.mT` to transpose batches of matrices or `x.permute(*torch.arange(x.ndim - 1, -1, -1))` to reverse the dimensions of a tensor. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3683.)
#   loss = (loss_vec.T @ weights[indices]) / loss_vec.size(0)
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 0 Test acc:  0.8037500008940697 adv acc:  0.3890624973922968
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 1 Test acc:  0.8065625011920929 adv acc:  0.3718750011175871
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 2 Test acc:  0.8018750041723252 adv acc:  0.35156249925494193
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 3 Test acc:  0.8037499949336052 adv acc:  0.3421874985098839
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 4 Test acc:  0.7987500011920929 adv acc:  0.323437499627471
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 5 Test acc:  0.8203125 adv acc:  0.3259374998509884
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 6 Test acc:  0.8156250014901161 adv acc:  0.3143750004470348
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 7 Test acc:  0.8209374964237213 adv acc:  0.320312499627471
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 8 Test acc:  0.8143749997019768 adv acc:  0.31843749843537805
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 9 Test acc:  0.8190625011920929 adv acc:  0.3224999990314245
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 10 Test acc:  0.8115624979138374 adv acc:  0.3081249985843897
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 11 Test acc:  0.8174999952316284 adv acc:  0.3221875011920929
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 12 Test acc:  0.8137499943375588 adv acc:  0.3087499991059303
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 13 Test acc:  0.8118750020861626 adv acc:  0.31093750074505805
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 14 Test acc:  0.8143749997019768 adv acc:  0.31499999910593035
# Test acc:  0.8062499985098839 adv acc:  0.4093749985098839
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 0 Test acc:  0.7949999988079071 adv acc:  0.38999999947845937
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 1 Test acc:  0.8071875020861625 adv acc:  0.3928125001490116
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 2 Test acc:  0.797812496125698 adv acc:  0.3887499995529652
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 3 Test acc:  0.801249997317791 adv acc:  0.37718750163912773
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 4 Test acc:  0.7931249976158142 adv acc:  0.37562499903142454
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 5 Test acc:  0.7865624949336052 adv acc:  0.37031249701976776
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 6 Test acc:  0.793437497317791 adv acc:  0.37062499932944776
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 7 Test acc:  0.7909374967217445 adv acc:  0.3715624988079071
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 8 Test acc:  0.7978124931454659 adv acc:  0.37249999940395356
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 9 Test acc:  0.7996874988079071 adv acc:  0.3731250002980232
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 10 Test acc:  0.8006250008940696 adv acc:  0.3681250002235174
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 11 Test acc:  0.7962500020861626 adv acc:  0.3653124999254942
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 12 Test acc:  0.7990625008940697 adv acc:  0.37093749828636646
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 13 Test acc:  0.7896875008940697 adv acc:  0.35499999932944776
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 14 Test acc:  0.8006250068545342 adv acc:  0.36343750171363354
# Test acc:  0.8009375035762787 adv acc:  0.3934375006705523
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 0 Test acc:  0.8065624922513962 adv acc:  0.3893750000745058
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 1 Test acc:  0.7915624961256981 adv acc:  0.38124999962747097
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 2 Test acc:  0.803125 adv acc:  0.3768750000745058
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 3 Test acc:  0.8015624985098839 adv acc:  0.3706250011920929
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 4 Test acc:  0.7896874979138374 adv acc:  0.3731249991804361
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 5 Test acc:  0.7859374970197678 adv acc:  0.36687499955296515
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 6 Test acc:  0.7912499979138374 adv acc:  0.3731249991804361
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 7 Test acc:  0.7834374949336051 adv acc:  0.3559374988079071
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 8 Test acc:  0.7903125032782554 adv acc:  0.3700000006705523
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 9 Test acc:  0.7862499982118607 adv acc:  0.3549999989569187
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 10 Test acc:  0.7793750017881393 adv acc:  0.35718749836087227
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 11 Test acc:  0.779374997317791 adv acc:  0.3578124985098839
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 12 Test acc:  0.7806250035762787 adv acc:  0.3606249995529652
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 13 Test acc:  0.776249997317791 adv acc:  0.3568749982863665
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 14 Test acc:  0.7868749901652337 adv acc:  0.359374999627471
# Test acc:  0.8096875011920929 adv acc:  0.3999999985098839
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 0 Test acc:  0.8015624985098839 adv acc:  0.3940624982118607
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 1 Test acc:  0.7853124991059304 adv acc:  0.37406250052154066
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 2 Test acc:  0.7778125002980232 adv acc:  0.3640625011175871
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 3 Test acc:  0.7546875029802322 adv acc:  0.34687500074505806
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 4 Test acc:  0.7306250020861625 adv acc:  0.3287499979138374
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 5 Test acc:  0.7359375029802322 adv acc:  0.3243749998509884
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 6 Test acc:  0.7262499988079071 adv acc:  0.30812499932944776
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 7 Test acc:  0.7162499979138375 adv acc:  0.2993750017136335
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 8 Test acc:  0.7106250017881394 adv acc:  0.28406249843537806
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 9 Test acc:  0.7262500002980232 adv acc:  0.28749999962747097
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 10 Test acc:  0.7209374994039536 adv acc:  0.2706249997019768
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 11 Test acc:  0.7284374967217445 adv acc:  0.260937499627471
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 12 Test acc:  0.7184374973177909 adv acc:  0.2493749987334013
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 13 Test acc:  0.7228125020861625 adv acc:  0.24531249776482583
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 14 Test acc:  0.7312500014901161 adv acc:  0.24531250074505806
# Test acc:  0.7981249988079071 adv acc:  0.4034374997019768
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 0 Test acc:  0.8093749985098839 adv acc:  0.39281250052154065
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 1 Test acc:  0.8087500035762787 adv acc:  0.3790624994784594
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 2 Test acc:  0.8112499997019768 adv acc:  0.3746874999254942
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 3 Test acc:  0.8031250014901161 adv acc:  0.3512499999254942
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 4 Test acc:  0.8049999952316285 adv acc:  0.3384374987334013
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 5 Test acc:  0.8049999997019768 adv acc:  0.32093749977648256
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 6 Test acc:  0.8175000011920929 adv acc:  0.3181249987334013
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 7 Test acc:  0.8068750008940697 adv acc:  0.3012499984353781
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 8 Test acc:  0.8071874991059304 adv acc:  0.2884374991059303
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 9 Test acc:  0.7993749991059304 adv acc:  0.26374999843537805
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 10 Test acc:  0.8012499988079071 adv acc:  0.24937499985098838
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 11 Test acc:  0.8012500002980232 adv acc:  0.2381249986588955
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 12 Test acc:  0.8003124997019768 adv acc:  0.22468749880790712
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 13 Test acc:  0.7990624994039536 adv acc:  0.20406250115483998
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 14 Test acc:  0.8025000020861626 adv acc:  0.19093750044703484

# %%
import pickle

a = result_list

with open('saved_results/mixed_sweep/250127_5c1_median_arui_flatbeta.pk', 'wb') as handle:
    pickle.dump(a, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
# with open('saved_results/mixed_sweep/240131_03_harder.pk', 'rb') as handle:
#     result_list = pickle.load(handle)

# %%
import matplotlib.pyplot as plt
import numpy as np

font = {'family' : 'normal',
        'weight' : 'normal',
        'size'   : 18}

plt.rc('font', **font)
plt.figure(dpi=80, figsize=(6,4))

plot_settings = [[10,1],[15 ,1],[17,1], [20,1],[25,1]]

num_aru = [10, 15, 17, 20, 25]
beta_params = [0.05, 0.05, 0.05, 0.05, 0.05]
weight2_list = [1, 1, 1, 1, 1]

# Generate some sample data
x = range(num_rounds+1)  # 100 points from 0 to 10

# Plotting the lines
# plt.plot(x, y1, label='Test Acc')
label_list = plot_settings
for i in range(len(label_list)):
    y = np.array(result_list[i]['adv_acc'])
    error = np.array(result_list[i]['adv_std'])
    plt.plot(x, y, label= str(label_list[i]))
    plt.fill_between(x, y-error, y+error,
    alpha=0.2)

# Adding labels and title
plt.xlabel('Injection Rounds')
plt.ylabel('Adv. Acc. (Robustness)')
plt.title('ARU vs Median \n Legend - [#ARU client, scale: β]', fontsize = 'medium')

# Adding a legend
plt.legend( loc="best", fontsize='small')


# Display the plot
plt.show()

# %% [raw]
# 250127_5c1_median_arui_flatbeta
# plot_settings = [[10,1],[15 ,1],[17,1], [20,1],[25,1]]
