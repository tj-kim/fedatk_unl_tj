# %% [markdown]
# ### Multiround UNL Attack Mixed
#
# Figure 5abc, and 6c
# Adjust the aggregation method accordingly based on hyperparameters (trimmed mean cutoff) to replicate results
#
# Can also use this code to perform experiments for table 2
#
# ##### Summary
# Load FAT model trained for 150 rounds and for 50 rounds try and inject FedAvg model into the system. Try different scaling rates and spread out the model replacement attack.

# %%
cd /home/ubuntu/fedatk_unl_tj/
# Out:
# /home/ubuntu/fedatk_unl_tj

# %%
# Import General Libraries
import os
import argparse
import torch
import copy
import pickle
import random
import numpy as np
import pandas as pd

# Import FedEM based Libraries
from utils.utils import *
from utils.constants import *
from utils.args import *
from utils.util_notebooks import *
from run_experiment import *
from models import *

# Import Transfer Attack
from transfer_attacks.Personalized_NN import *
from transfer_attacks.Params import *
from transfer_attacks.Transferer import *
from transfer_attacks.Args import *
from transfer_attacks.TA_utils import *
# Out:
# /home/ubuntu/anaconda3/envs/FedEM_env/lib/python3.9/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /home/ubuntu/anaconda3/envs/FedEM_env/lib/python3.9/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.2' currently installed).
#   from pandas.core import (

# %%
# Specify aggregation method, number of clients, and dataset
setting, num_user = "FedAvg_adv", 40
exp = "cifar10"

# Load models for FAT and FedAvg - write down path to where weights are saved
save_path_FAT = '/home/ubuntu/fedatk_unl_tj/weights/cifar10/250123_icml25/FAT/'
save_path_FedAvg =  '/home/ubuntu/fedatk_unl_tj/weights/cifar10/250123_icml25/FedAvg/'
# save_path_FAT = '/home/ubuntu/fedatk_unl_tj/weights/fakenews/250119_small_architecture_moreconv/FAT_ep02/'
# save_path_FedAvg =  '/home/ubuntu/fedatk_unl_tj/weights/fakenews/250119_small_architecture_moreconv/FedAvg/'

# Attack parameters for performing PGD 
eps_attack = 4.0
eps_train = 4.5
step_size = 0.01
steps = 10

# %%
# Generate instance of aggregator that holds all clients, data and models and load relevant models in
try: # Skip loading if already loaded
    aggregator_og
except:
    aggregator_og, clients, args_ = set_args(setting, num_user,  experiment = exp) # Indicate dataset here

model_FAT = copy.deepcopy(import_model_weights(num_user, setting, save_path_FAT, aggregator_og, args_)[0])
model_Fedavg = copy.deepcopy(import_model_weights(num_user, setting, save_path_FedAvg, aggregator_og, args_)[0])

# Obtain parameters for each layer
params_FAT = model_FAT.state_dict()
params_FedAvg = model_Fedavg.state_dict()

# Just take the values of weights and bias for the model
desired_keys = params_FAT.keys() # [key for key in params_FAT.keys() if 'weight' in key or 'bias' in key] #
# Out:
# ==> Clients initialization..
# ===> Building data iterators..
#  49%|████▉     | 39/80 [00:00<00:00, 120.86it/s]
# ===> Initializing clients..
#   0%|          | 0/40 [00:00<?, ?it/s]/home/ubuntu/anaconda3/envs/FedEM_env/lib/python3.9/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/ubuntu/anaconda3/envs/FedEM_env/lib/python3.9/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=MobileNet_V2_Weights.IMAGENET1K_V1`. You can also use `weights=MobileNet_V2_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# 100%|██████████| 40/40 [00:21<00:00,  1.85it/s]
# /home/ubuntu/fedatk_unl_tj/aggregator.py:289: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   learner.model.load_state_dict(torch.load(chkpts_path))

# %%
num_aru = [5, 5, 10, 10]
beta_params = [0.05, 0.1, 0.1, 0.2]
weight2_list = [0.3, 0.2, 0.3, 0.2]
agg_options = ["trimmed_mean", "trimmed_mean", "trimmed_mean","trimmed_mean"]

num_rounds = 20
eps = eps_attack

result_list = []
for itt in range(len(num_aru)):
    result_list += [{}]

# setting, num_user = "FedAvg_adv", 20
save_path_FedAvg_150R = '/home/ubuntu/fedatk_unl_tj/weights/cifar10/250123_icml25/FAT_R50/'
aggregator, clients, args_ = set_args(setting, num_user,  experiment = exp)

agg_choice = random.choices(range(3),k=num_rounds)

if True:
    print("updating adv data set")
    # add adv dataset update
    Fu = np.zeros(num_user)
    Fu[0:25] = 1

    # Setting evasion attack parameters
    x_min = torch.min(clients[0].adv_nn.dataloader.x_data)
    x_max = torch.max(clients[0].adv_nn.dataloader.x_data)
    atk_params = PGD_Params()
    atk_params.set_params(batch_size=1, iteration = 10,
                    target = -1, x_val_min = x_min, x_val_max = x_max,
                    step_size = 0.05, step_norm = "inf", eps = eps, eps_norm = 2)

    # Assign proportion and attack params
    for c in range(len(clients)):
        if Fu[c] > 0:
            aggregator.clients[c].set_adv_params(Fu[c], atk_params)
            aggregator.clients[c].update_advnn()
            aggregator.clients[c].assign_advdataset()

for itt in range(len(beta_params)):
    # Perform 50 rounds of FAT on FedAvg model 
    num_adv = num_aru[itt]
    weight2 = 1/num_adv * weight2_list[itt]
    adv_id = random.sample(range(25,num_user), num_adv) # excluding 0-9 as Fu = 1
    beta = beta_params[itt]

    test_acc_gather = []
    adv_acc_gather = []
    test_acc_std = []
    adv_acc_std = []
    cosine_gather_layers = np.zeros([num_rounds, len(desired_keys)])

    aggregator.tm_rate = beta

    # Test performance of aggregator on data 
    aggregator.load_state(dir_path = save_path_FedAvg_150R)
    aggregator.update_clients()
    model_FA = pull_model_from_agg(aggregator)
    model_FA.eval()
    acc, adv_acc = get_adv_acc(aggregator, model_FA, eps = eps)

    # prev_model = copy.deepcopy(model_FA)

    print("Test acc: ", np.mean(acc), "adv acc: ", np.mean(adv_acc))
    test_acc_gather+= [np.mean(acc)]
    adv_acc_gather += [np.mean(adv_acc)]
    test_acc_std += [np.std(acc)]
    adv_acc_std += [np.std(adv_acc)]



    for i in range(num_rounds):

        # Per round Freq
        aggregator.aggregation_op = agg_options[itt]

        # aggregator.mix()
        UNL_mix(aggregator, adv_id, model_inject = model_Fedavg, keys = desired_keys, weight_scale_2 = weight2, dump_flag=False, tm_beta=beta)
        model_overfit = pull_model_from_agg(aggregator)
        model_overfit.eval()
        acc, adv_acc = get_adv_acc(aggregator, model_overfit, eps = eps)

        print("round", i,"Test acc: ", np.mean(acc), "adv acc: ", np.mean(adv_acc))
        test_acc_gather+= [np.mean(acc)]
        adv_acc_gather += [np.mean(adv_acc)]
        test_acc_std += [np.std(acc)]
        adv_acc_std += [np.std(adv_acc)]
        # prev_model = copy.deepcopy(model_overfit)

        result_list[itt]['test_acc'] = copy.deepcopy(test_acc_gather)
        result_list[itt]['adv_acc'] = copy.deepcopy(adv_acc_gather)
        result_list[itt]['test_std'] = copy.deepcopy(test_acc_std)
        result_list[itt]['adv_std'] = copy.deepcopy(adv_acc_std)
        result_list[itt]['num_clients'] = num_adv
        result_list[itt]['beta'] = beta
        result_list[itt]['weight2'] = weight2_list[itt]
        # Perform gradient direction gathering

        del model_overfit
        gc.collect()
        torch.cuda.empty_cache()
# Out:
# ==> Clients initialization..
# ===> Building data iterators..
#  49%|████▉     | 39/80 [00:00<00:00, 126.92it/s]
# ===> Initializing clients..
# 100%|██████████| 40/40 [00:23<00:00,  1.73it/s]
# updating adv data set
# Test acc:  0.8109374985098838 adv acc:  0.4003124989569187
# trimmed mean, N removed:  2
# weight scale:
#  [36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00
#  36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00
#  36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00
#  36.00 36.00 36.00 36.00]
# /home/ubuntu/fedatk_unl_tj/learners/learner.py:192: UserWarning: The use of `x.T` on tensors of dimension other than 2 to reverse their shape is deprecated and it will throw an error in a future release. Consider `x.mT` to transpose batches of matrices or `x.permute(*torch.arange(x.ndim - 1, -1, -1))` to reverse the dimensions of a tensor. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3683.)
#   loss = (loss_vec.T @ weights[indices]) / loss_vec.size(0)
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 0 Test acc:  0.808125002682209 adv acc:  0.325000000372529
# trimmed mean, N removed:  2
# weight scale:
#  [36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00
#  36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00
#  36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00
#  36.00 36.00 36.00 36.00]
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 1 Test acc:  0.8118750005960464 adv acc:  0.2393750000745058
# trimmed mean, N removed:  2
# weight scale:
#  [36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00
#  36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00
#  36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00
#  36.00 36.00 36.00 36.00]
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 2 Test acc:  0.8287499994039536 adv acc:  0.15187500026077033
# trimmed mean, N removed:  2
# weight scale:
#  [36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00
#  36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00
#  36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00
#  36.00 36.00 36.00 36.00]
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 3 Test acc:  0.8296874985098839 adv acc:  0.10468750088475645
# trimmed mean, N removed:  2
# weight scale:
#  [36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00
#  36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00
#  36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00
#  36.00 36.00 36.00 36.00]
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 4 Test acc:  0.8456250011920929 adv acc:  0.07000000081025064
# trimmed mean, N removed:  2
# weight scale:
#  [36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00
#  36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00
#  36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00
#  36.00 36.00 36.00 36.00]
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 5 Test acc:  0.8575000017881393 adv acc:  0.05000000093132258
# trimmed mean, N removed:  2
# weight scale:
#  [36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00
#  36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00
#  36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00
#  36.00 36.00 36.00 36.00]
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 6 Test acc:  0.8518750011920929 adv acc:  0.039687500707805155
# trimmed mean, N removed:  2
# weight scale:
#  [36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00
#  36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00
#  36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00
#  36.00 36.00 36.00 36.00]
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 7 Test acc:  0.8556250020861625 adv acc:  0.027187500544823707
# trimmed mean, N removed:  2
# weight scale:
#  [36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00
#  36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00
#  36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00
#  36.00 36.00 36.00 36.00]
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 8 Test acc:  0.8537499979138374 adv acc:  0.021875000535510482
# trimmed mean, N removed:  2
# weight scale:
#  [36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00
#  36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00
#  36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00
#  36.00 36.00 36.00 36.00]
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 9 Test acc:  0.8546874970197678 adv acc:  0.016875000367872418
# trimmed mean, N removed:  2
# weight scale:
#  [36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00
#  36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00
#  36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00
#  36.00 36.00 36.00 36.00]
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 10 Test acc:  0.853125 adv acc:  0.015312500298023224
# trimmed mean, N removed:  2
# weight scale:
#  [36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00
#  36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00
#  36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00
#  36.00 36.00 36.00 36.00]
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 11 Test acc:  0.8543750017881393 adv acc:  0.015312500298023224
# trimmed mean, N removed:  2
# weight scale:
#  [36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00
#  36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00
#  36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00
#  36.00 36.00 36.00 36.00]
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 12 Test acc:  0.848124997317791 adv acc:  0.012500000279396772
# trimmed mean, N removed:  2
# weight scale:
#  [36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00
#  36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00
#  36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00
#  36.00 36.00 36.00 36.00]
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 13 Test acc:  0.850625005364418 adv acc:  0.010625000181607901
# trimmed mean, N removed:  2
# weight scale:
#  [36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00
#  36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00
#  36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00
#  36.00 36.00 36.00 36.00]
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 14 Test acc:  0.8534375011920929 adv acc:  0.010312500200234354
# trimmed mean, N removed:  2
# weight scale:
#  [36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00
#  36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00
#  36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00
#  36.00 36.00 36.00 36.00]
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 15 Test acc:  0.8468750014901161 adv acc:  0.013437500200234353
# trimmed mean, N removed:  2
# weight scale:
#  [36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00
#  36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00
#  36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00
#  36.00 36.00 36.00 36.00]
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 16 Test acc:  0.8631249994039536 adv acc:  0.010625000204890966
# trimmed mean, N removed:  2
# weight scale:
#  [36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00
#  36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00
#  36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00
#  36.00 36.00 36.00 36.00]
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 17 Test acc:  0.8487499997019767 adv acc:  0.009687500190921128
# trimmed mean, N removed:  2
# weight scale:
#  [36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00
#  36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00
#  36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00
#  36.00 36.00 36.00 36.00]
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 18 Test acc:  0.8496874988079071 adv acc:  0.009062500228174031
# trimmed mean, N removed:  2
# weight scale:
#  [36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00
#  36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00
#  36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00 36.00
#  36.00 36.00 36.00 36.00]
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 19 Test acc:  0.8499999985098838 adv acc:  0.010937500186264515
# Test acc:  0.805624996125698 adv acc:  0.41093749888241293
# trimmed mean, N removed:  4
# weight scale:
#  [32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00]
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 0 Test acc:  0.7965625017881394 adv acc:  0.39156249947845934
# trimmed mean, N removed:  4
# weight scale:
#  [32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00]
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 1 Test acc:  0.8037499964237214 adv acc:  0.36812499798834325
# trimmed mean, N removed:  4
# weight scale:
#  [32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00]
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 2 Test acc:  0.8125000029802323 adv acc:  0.369999997317791
# trimmed mean, N removed:  4
# weight scale:
#  [32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00]
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 3 Test acc:  0.8184375032782555 adv acc:  0.33968749903142453
# trimmed mean, N removed:  4
# weight scale:
#  [32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00]
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 4 Test acc:  0.8146875008940697 adv acc:  0.3256249986588955
# trimmed mean, N removed:  4
# weight scale:
#  [32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00]
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 5 Test acc:  0.8159374982118607 adv acc:  0.31531249918043613
# trimmed mean, N removed:  4
# weight scale:
#  [32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00]
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 6 Test acc:  0.8215624988079071 adv acc:  0.30718749910593035
# trimmed mean, N removed:  4
# weight scale:
#  [32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00]
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 7 Test acc:  0.8196875020861626 adv acc:  0.2868749998509884
# trimmed mean, N removed:  4
# weight scale:
#  [32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00]
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 8 Test acc:  0.81875 adv acc:  0.2671874985098839
# trimmed mean, N removed:  4
# weight scale:
#  [32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00]
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 9 Test acc:  0.823124997317791 adv acc:  0.2512499999254942
# trimmed mean, N removed:  4
# weight scale:
#  [32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00]
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 10 Test acc:  0.8149999961256981 adv acc:  0.23718749918043613
# trimmed mean, N removed:  4
# weight scale:
#  [32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00]
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 11 Test acc:  0.8228124961256981 adv acc:  0.2234374988824129
# trimmed mean, N removed:  4
# weight scale:
#  [32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00]
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 12 Test acc:  0.8306249991059304 adv acc:  0.2021874977275729
# trimmed mean, N removed:  4
# weight scale:
#  [32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00]
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 13 Test acc:  0.8168749988079071 adv acc:  0.18531249817460776
# trimmed mean, N removed:  4
# weight scale:
#  [32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00]
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 14 Test acc:  0.8234374970197678 adv acc:  0.1737499998882413
# trimmed mean, N removed:  4
# weight scale:
#  [32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00]
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 15 Test acc:  0.8268750056624412 adv acc:  0.16781250052154065
# trimmed mean, N removed:  4
# weight scale:
#  [32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00]
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 16 Test acc:  0.826249997317791 adv acc:  0.1449999999254942
# trimmed mean, N removed:  4
# weight scale:
#  [32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00]
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 17 Test acc:  0.821562497317791 adv acc:  0.13781250026077033
# trimmed mean, N removed:  4
# weight scale:
#  [32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00]
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 18 Test acc:  0.8225000068545342 adv acc:  0.12281250059604645
# trimmed mean, N removed:  4
# weight scale:
#  [32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00]
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 19 Test acc:  0.8246875047683716 adv acc:  0.1196875001071021
# Test acc:  0.8025000020861626 adv acc:  0.3978124983608723
# trimmed mean, N removed:  4
# weight scale:
#  [32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00]
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 0 Test acc:  0.8103125020861626 adv acc:  0.34656249769032
# trimmed mean, N removed:  4
# weight scale:
#  [32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00]
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 1 Test acc:  0.8128124997019768 adv acc:  0.26468750089406967
# trimmed mean, N removed:  4
# weight scale:
#  [32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00]
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 2 Test acc:  0.8193750023841858 adv acc:  0.1946875000372529
# trimmed mean, N removed:  4
# weight scale:
#  [32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00]
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 3 Test acc:  0.8215624958276748 adv acc:  0.1259375000372529
# trimmed mean, N removed:  4
# weight scale:
#  [32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00]
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 4 Test acc:  0.8415625005960464 adv acc:  0.10062500028870999
# trimmed mean, N removed:  4
# weight scale:
#  [32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00]
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 5 Test acc:  0.8490624994039535 adv acc:  0.0668750011594966
# trimmed mean, N removed:  4
# weight scale:
#  [32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00]
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 6 Test acc:  0.8400000020861625 adv acc:  0.05218750073108822
# trimmed mean, N removed:  4
# weight scale:
#  [32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00]
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 7 Test acc:  0.8521875008940697 adv acc:  0.035937500768341124
# trimmed mean, N removed:  4
# weight scale:
#  [32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00]
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 8 Test acc:  0.849687497317791 adv acc:  0.030625000735744833
# trimmed mean, N removed:  4
# weight scale:
#  [32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00]
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 9 Test acc:  0.8578124970197678 adv acc:  0.022812500433064997
# trimmed mean, N removed:  4
# weight scale:
#  [32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00]
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 10 Test acc:  0.8549999982118607 adv acc:  0.018750000419095157
# trimmed mean, N removed:  4
# weight scale:
#  [32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00]
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 11 Test acc:  0.85625 adv acc:  0.015625000325962903
# trimmed mean, N removed:  4
# weight scale:
#  [32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00]
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 12 Test acc:  0.8534375011920929 adv acc:  0.013125000288709998
# trimmed mean, N removed:  4
# weight scale:
#  [32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00]
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 13 Test acc:  0.8478125035762787 adv acc:  0.012500000256113707
# trimmed mean, N removed:  4
# weight scale:
#  [32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00]
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 14 Test acc:  0.8553125008940696 adv acc:  0.014687500288709998
# trimmed mean, N removed:  4
# weight scale:
#  [32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00]
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 15 Test acc:  0.8534375011920929 adv acc:  0.010625000181607901
# trimmed mean, N removed:  4
# weight scale:
#  [32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00]
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 16 Test acc:  0.8528125002980232 adv acc:  0.009375000139698386
# trimmed mean, N removed:  4
# weight scale:
#  [32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00]
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 17 Test acc:  0.8543750032782554 adv acc:  0.008750000153668225
# trimmed mean, N removed:  4
# weight scale:
#  [32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00]
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 18 Test acc:  0.853125 adv acc:  0.0075000001350417735
# trimmed mean, N removed:  4
# weight scale:
#  [32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00 32.00
#  32.00 32.00 32.00 32.00]
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 19 Test acc:  0.8440625041723251 adv acc:  0.010312500200234354
# Test acc:  0.7996875017881393 adv acc:  0.39718749970197675
# trimmed mean, N removed:  8
# weight scale:
#  [24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00
#  24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00
#  24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00
#  24.00 24.00 24.00 24.00]
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 0 Test acc:  0.8031250014901161 adv acc:  0.3840624984353781
# trimmed mean, N removed:  8
# weight scale:
#  [24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00
#  24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00
#  24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00
#  24.00 24.00 24.00 24.00]
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 1 Test acc:  0.8056250035762786 adv acc:  0.3712499998509884
# trimmed mean, N removed:  8
# weight scale:
#  [24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00
#  24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00
#  24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00
#  24.00 24.00 24.00 24.00]
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 2 Test acc:  0.8006249979138375 adv acc:  0.36187499985098837
# trimmed mean, N removed:  8
# weight scale:
#  [24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00
#  24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00
#  24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00
#  24.00 24.00 24.00 24.00]
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 3 Test acc:  0.8109374925494194 adv acc:  0.34437500052154063
# trimmed mean, N removed:  8
# weight scale:
#  [24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00
#  24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00
#  24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00
#  24.00 24.00 24.00 24.00]
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 4 Test acc:  0.8137499988079071 adv acc:  0.3368750013411045
# trimmed mean, N removed:  8
# weight scale:
#  [24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00
#  24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00
#  24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00
#  24.00 24.00 24.00 24.00]
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 5 Test acc:  0.8121875017881394 adv acc:  0.3193750001490116
# trimmed mean, N removed:  8
# weight scale:
#  [24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00
#  24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00
#  24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00
#  24.00 24.00 24.00 24.00]
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 6 Test acc:  0.8087499976158142 adv acc:  0.30281249769032004
# trimmed mean, N removed:  8
# weight scale:
#  [24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00
#  24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00
#  24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00
#  24.00 24.00 24.00 24.00]
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 7 Test acc:  0.8143749967217445 adv acc:  0.2815624997019768
# trimmed mean, N removed:  8
# weight scale:
#  [24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00
#  24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00
#  24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00
#  24.00 24.00 24.00 24.00]
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 8 Test acc:  0.813437496125698 adv acc:  0.27781249992549417
# trimmed mean, N removed:  8
# weight scale:
#  [24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00
#  24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00
#  24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00
#  24.00 24.00 24.00 24.00]
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 9 Test acc:  0.8215625002980232 adv acc:  0.2515624988824129
# trimmed mean, N removed:  8
# weight scale:
#  [24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00
#  24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00
#  24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00
#  24.00 24.00 24.00 24.00]
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 10 Test acc:  0.8149999991059304 adv acc:  0.2296874988824129
# trimmed mean, N removed:  8
# weight scale:
#  [24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00
#  24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00
#  24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00
#  24.00 24.00 24.00 24.00]
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 11 Test acc:  0.8121875002980232 adv acc:  0.2190624985843897
# trimmed mean, N removed:  8
# weight scale:
#  [24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00
#  24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00
#  24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00
#  24.00 24.00 24.00 24.00]
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 12 Test acc:  0.8178124979138375 adv acc:  0.20937499925494193
# trimmed mean, N removed:  8
# weight scale:
#  [24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00
#  24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00
#  24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00
#  24.00 24.00 24.00 24.00]
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 13 Test acc:  0.819375005364418 adv acc:  0.1950000010430813
# trimmed mean, N removed:  8
# weight scale:
#  [24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00
#  24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00
#  24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00
#  24.00 24.00 24.00 24.00]
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 14 Test acc:  0.8146875023841857 adv acc:  0.1765625
# trimmed mean, N removed:  8
# weight scale:
#  [24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00
#  24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00
#  24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00
#  24.00 24.00 24.00 24.00]
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 15 Test acc:  0.8278124988079071 adv acc:  0.16281249979510903
# trimmed mean, N removed:  8
# weight scale:
#  [24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00
#  24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00
#  24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00
#  24.00 24.00 24.00 24.00]
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 16 Test acc:  0.8156250014901161 adv acc:  0.13999999966472387
# trimmed mean, N removed:  8
# weight scale:
#  [24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00
#  24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00
#  24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00
#  24.00 24.00 24.00 24.00]
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 17 Test acc:  0.8271874994039535 adv acc:  0.1340624990873039
# trimmed mean, N removed:  8
# weight scale:
#  [24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00
#  24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00
#  24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00
#  24.00 24.00 24.00 24.00]
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 18 Test acc:  0.8178124994039535 adv acc:  0.1275000018067658
# trimmed mean, N removed:  8
# weight scale:
#  [24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00
#  24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00
#  24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00 24.00
#  24.00 24.00 24.00 24.00]
# Successfully copied values of 'features.17.conv.1.1.running_var' from source_model to target_model.
# Values of 'features.17.conv.1.1.running_var' successfully updated in the new model.
# round 19 Test acc:  0.8318750008940696 adv acc:  0.12093749982304872

# %%
import pickle

a = result_list

with open('saved_results/mixed_sweep/250128_5b_tm_arui_2.pk', 'wb') as handle:
    pickle.dump(a, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
# with open('saved_results/mixed_sweep/250127_5b_tm_arui_2.pk', 'rb') as handle:
#     result_list = pickle.load(handle)

# %%
import matplotlib.pyplot as plt
import numpy as np

font = {'family' : 'normal',
        'weight' : 'normal',
        'size'   : 18}

plt.rc('font', **font)
plt.figure(dpi=80, figsize=(6,4))

plot_settings = [[5 ,0.05,0.3],[5 ,0.1, 0.2],[10, 0.1, 0.3], [10, 0.2, 0.2]]

# Generate some sample data
x = range(num_rounds+1)  # 100 points from 0 to 10

# Plotting the lines
# plt.plot(x, y1, label='Test Acc')
label_list = plot_settings
for i in range(len(label_list)):
    y = np.array(result_list[i]['adv_acc'])
    error = np.array(result_list[i]['adv_std'])
    plt.plot(x, y, label= str(label_list[i]))
    plt.fill_between(x, y-error, y+error,
    alpha=0.2)

# Adding labels and title
plt.xlabel('Injection Rounds')
plt.ylabel('Adv. Acc. (Robustness)')
plt.title('CIFAR-10: ARU vs Trimmed Mean \n Legend - [#ARU client, tm_param, β]', fontsize = 'medium')

# Adding a legend
plt.legend( loc="best", fontsize='small')


# Display the plot
plt.show()
# Out:
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.

# %% [raw]
# 'saved_results/mixed_sweep/250127_5b_tm_arui.pk'
# plot_settings = [[5 ,0.05,0.3],[5 ,0.2, 0.05],[5, 0.2, 0.1], [10, 0.2, 0.15]]
# num_round = 15
#
# 'saved_results/mixed_sweep/250127_5b_tm_arui_2.pk'
# plot_settings = [[5 ,0.05,0.3],[5 ,0.1, 0.2],[10, 0.1, 0.3], [10, 0.2, 0.2]]
# num_round = 20
